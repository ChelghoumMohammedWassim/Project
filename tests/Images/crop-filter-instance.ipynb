# %%
import sys
sys.path.append('../..') 
import numpy as np
import cv2 as cv
import os
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from keras import layers
from tensorflow import keras
import gc
import matplotlib.pyplot as plt
from tools.GA.FilterGeneticAlgorithm import FilterGeneticAlgorithm
import random as rnd
from tools.GA.CropGeneticAlgorithm import CropGeneticAlgorithm

# %%
path = "../datasets/Images/Skin canser"

items = os.listdir(path)

folder_paths = [path+"/"+item for item in items if os.path.isdir(os.path.join(path, item))]

for path in folder_paths:
    print(path)
# Out:
# ../datasets/Images/Skin canser/benign
# ../datasets/Images/Skin canser/malignant

# %%
def get_Data(folder_path,cls):
    X = []
    Y=[]
    for root, directories, files in os.walk(folder_path):
        for filename in files:
            img=cv.imread(os.path.join(root, filename))
            img=cv.cvtColor(img, cv.COLOR_RGB2BGR)
            img=cv.resize(img, (224,224))
            X.append(img)
            Y.append(cls)
    return X,Y

# %%
X=[]
Y=[]

for cls,folder_path in enumerate(folder_paths):
    x,y=get_Data(folder_path,cls)
    X=X+x
    Y=Y+y

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,test_size=0.3)

# %%
X_train=np.array(X_train)
Y_train=np.array(Y_train)
X_test=np.array(X_test)
Y_test=np.array(Y_test)

print(f"X_train:{X_train.shape} Y_train:{Y_train.shape} X_test:{X_test.shape} Y_test:{Y_test.shape}")
# Out:
# X_train:(2307, 224, 224, 3) Y_train:(2307,) X_test:(990, 224, 224, 3) Y_test:(990,)

# %%
model = keras.models.Sequential([
    layers.BatchNormalization(input_shape=(224, 224, 3)),
    layers.Conv2D(16, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Dense(64, activation='relu'),
    layers.Flatten(),
    layers.Dense(2, activation='softmax')
])

# %%
kf = KFold(n_splits=10, random_state=42, shuffle=True)
splits = list(kf.split(X_test))

# %%
kf = KFold(n_splits=10, random_state=42, shuffle=True)
evaluations=0

for train_index, test_index in splits.copy():
    m= keras.models.clone_model(model)

    m.compile(optimizer="adam", loss=keras.losses.SparseCategoricalCrossentropy(), metrics=['accuracy'])

    train_index, test_index = train_index.tolist(), test_index.tolist()
    x_train, x_test, y_train, y_test = np.array(X_test)[train_index], np.array(X_test)[test_index], np.array(Y_test)[train_index], np.array(Y_test)[test_index]

    m.fit(x_train, y_train, epochs=1, batch_size=32)
    evaluations+=m.evaluate(x_test,y_test)[1]

    gc.collect()
print(evaluations/10)
# Out:
# 28/28 [==============================] - 34s 78ms/step - loss: 2.1689 - accuracy: 0.6891
# 4/4 [==============================] - 0s 45ms/step - loss: 0.9540 - accuracy: 0.7879
# 28/28 [==============================] - 2s 62ms/step - loss: 1.2569 - accuracy: 0.7015
# 4/4 [==============================] - 0s 15ms/step - loss: 1.3220 - accuracy: 0.6970
# 28/28 [==============================] - 2s 62ms/step - loss: 1.0926 - accuracy: 0.7127
# 4/4 [==============================] - 0s 15ms/step - loss: 2.2949 - accuracy: 0.5556
# 28/28 [==============================] - 2s 63ms/step - loss: 3.0665 - accuracy: 0.6510
# 8/8 [==============================] - 0s 18ms/step - loss: 1.6571 - accuracy: 0.6348
# crop [(0, 112.0), (0, 112.0)] fit: 0.6055166602134705
# --------------------------------------------------------------------------------
# 65/65 [==============================] - 5s 63ms/step - loss: 1.0279 - accuracy: 0.7081
# 8/8 [==============================] - 0s 25ms/step - loss: 1.1041 - accuracy: 0.6277
# 65/65 [==============================] - 4s 62ms/step - loss: 0.6444 - accuracy: 0.7370
# 8/8 [==============================] - 0s 18ms/step - loss: 1.1603 - accuracy: 0.6537
# 65/65 [==============================] - 4s 63ms/step - loss: 0.8623 - accuracy: 0.7163
# 8/8 [==============================] - 0s 18ms/step - loss: 1.5486 - accuracy: 0.6667
# 65/65 [==============================] - 4s 62ms/step - loss: 0.7713 - accuracy: 0.6912
# 8/8 [==============================] - 0s 18ms/step - loss: 1.1292 - accuracy: 0.6104
# 65/65 [==============================] - 4s 62ms/step - loss: 1.0386 - accuracy: 0.7139
# 8/8 [==============================] - 0s 17ms/step - loss: 1.5602 - accuracy: 0.6234
# 65/65 [==============================] - 4s 61ms/step - loss: 0.9458 - accuracy: 0.7052
# 8/8 [==============================] - 0s 18ms/step - loss: 4.1406 - accuracy: 0.5844
# 65/65 [==============================] - 4s 63ms/step - loss: 0.6577 - accuracy: 0.7259
# 8/8 [==============================] - 0s 18ms/step - loss: 3.1373 - accuracy: 0.5628
# 65/65 [==============================] - 4s 62ms/step - loss: 1.3495 - accuracy: 0.6962
# 8/8 [==============================] - 0s 18ms/step - loss: 0.7649 - accuracy: 0.6304
# 65/65 [==============================] - 5s 64ms/step - loss: 1.0530 - accuracy: 0.7063
# 8/8 [==============================] - 0s 18ms/step - loss: 2.5362 - accuracy: 0.5652
# 65/65 [==============================] - 5s 64ms/step - loss: 1.1057 - accuracy: 0.7169
# 8/8 [==============================] - 0s 18ms/step - loss: 1.0754 - accuracy: 0.6652
# crop [(172, 220), (49, 221)] fit: 0.6189873874187469
# #################################################################################################################################################################
#
# generation: 0 best crop :[(172, 220), (49, 221)] fit: 0.6189873874187469
#
# #################################################################################################################################################################

# %%
cropped_X_train=np.array(cropGeneticAlgorithm.get_newData(X_train,best_crop.crop_dimension))
cropped_X_test=np.array(cropGeneticAlgorithm.get_newData(X_test,best_crop.crop_dimension))

print(f"X_train:{cropped_X_train.shape} Y_train:{Y_train.shape} X_test:{cropped_X_test.shape} Y_test:{Y_test.shape}")
# Out:
# X_train:(2307, 224, 224, 3) Y_train:(2307,) X_test:(990, 224, 224, 3) Y_test:(990,)

# %%
index=rnd.randint(0,len(X_test))

fig, (ax1, ax2) = plt.subplots(1, 2)

ax1.imshow(X_test[index])
ax1.set_title('Original')

ax2.imshow(cropped_X_test[index])
ax2.set_title('New')

plt.show()

# %%
evaluations=0

for train_index, test_index in splits.copy():
    m= keras.models.clone_model(model)

    m.compile(optimizer="adam", loss=keras.losses.SparseCategoricalCrossentropy(), metrics=['accuracy'])

    train_index, test_index = train_index.tolist(), test_index.tolist()
    x_train, x_test, y_train, y_test = np.array(cropped_X_test)[train_index], np.array(cropped_X_test)[test_index], np.array(Y_test)[train_index], np.array(Y_test)[test_index]

    m.fit(x_train, y_train, epochs=1, batch_size=32)
    evaluations+=m.evaluate(x_test,y_test)[1]

    gc.collect()
print(evaluations/10)
# Out:
# 28/28 [==============================] - 2s 67ms/step - loss: 1.4558 - accuracy: 0.6655
# 4/4 [==============================] - 0s 15ms/step - loss: 6.2406 - accuracy: 0.5051
# 28/28 [==============================] - 2s 65ms/step - loss: 1.3957 - accuracy: 0.6678
# 4/4 [==============================] - 0s 15ms/step - loss: 0.9730 - accuracy: 0.7576
# 28/28 [==============================] - 2s 63ms/step - loss: 0.8171 - accuracy: 0.7452
# 4/4 [==============================] - 0s 15ms/step - loss: 5.9425 - accuracy: 0.6263
# 28/28 [==============================] - 2s 62ms/step - loss: 2.4111 - accuracy: 0.6577
# 4/4 [==============================] - 0s 15ms/step - loss: 5.7487 - accuracy: 0.5455
# 28/28 [==============================] - 2s 62ms/step - loss: 1.8349 - accuracy: 0.6386
# 4/4 [==============================] - 0s 15ms/step - loss: 2.2915 - accuracy: 0.7071
# 28/28 [==============================] - 2s 62ms/step - loss: 1.4883 - accuracy: 0.6734
# 4/4 [==============================] - 0s 15ms/step - loss: 11.4565 - accuracy: 0.4141
# 28/28 [==============================] - 2s 63ms/step - loss: 2.8608 - accuracy: 0.6409
# 4/4 [==============================] - 0s 15ms/step - loss: 4.3002 - accuracy: 0.5556
# 28/28 [==============================] - 2s 62ms/step - loss: 1.3144 - accuracy: 0.6734
# 4/4 [==============================] - 0s 15ms/step - loss: 15.8213 - accuracy: 0.5758
# 28/28 [==============================] - 2s 62ms/step - loss: 0.9489 - accuracy: 0.6981
# 4/4 [==============================] - 0s 15ms/step - loss: 6.0521 - accuracy: 0.5455
# 28/28 [==============================] - 2s 62ms/step - loss: 1.7192 - accuracy: 0.6790
# 4/4 [==============================] - 0s 15ms/step - loss: 1.2453 - accuracy: 0.6667
# 0.5898989915847779

# %%
filterGeneticAlgorithm=FilterGeneticAlgorithm(X_train=cropped_X_train,X_test=cropped_X_test,Y_train=Y_train,Y_test=Y_test, model=model, loss=keras.losses.SparseCategoricalCrossentropy())

# %%
best_filter= filterGeneticAlgorithm.run(generation_limit=1, population_size=2)
# Out:
# --------------------------------------------------------------------------------
# 65/65 [==============================] - 4s 63ms/step - loss: 0.7371 - accuracy: 0.7197
# 8/8 [==============================] - 0s 17ms/step - loss: 6.1456 - accuracy: 0.5368
# 65/65 [==============================] - 4s 63ms/step - loss: 1.1046 - accuracy: 0.7119
# 8/8 [==============================] - 0s 18ms/step - loss: 2.7045 - accuracy: 0.5281
# 65/65 [==============================] - 4s 62ms/step - loss: 0.9495 - accuracy: 0.6724
# 8/8 [==============================] - 0s 18ms/step - loss: 1.9097 - accuracy: 0.5584
# 65/65 [==============================] - 4s 62ms/step - loss: 1.3027 - accuracy: 0.6879
# 8/8 [==============================] - 0s 18ms/step - loss: 2.2791 - accuracy: 0.5758
# best filter :[0, 179, 0, 255, 0, 255, 0, 0, 0, 0, 5, 1, 1, 100, 200, 0] fit: 0.5829983055591583

# %%
filtered_X_train=np.array(filterGeneticAlgorithm.get_newData(cropped_X_train,filter=best_filter.filter))
filtered_X_test=np.array(filterGeneticAlgorithm.get_newData(cropped_X_test,filter=best_filter.filter))


print(f"X_train:{filtered_X_train.shape} Y_train:{Y_train.shape} X_test:{filtered_X_test.shape} Y_test:{Y_test.shape}")
# Out:
# X_train:(2307, 224, 224, 3) Y_train:(2307,) X_test:(990, 224, 224, 3) Y_test:(990,)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3)

ax1.imshow(X_test[index])
ax1.set_title('Original')

ax2.imshow(cropped_X_test[index])
ax2.set_title('cropped')

ax3.imshow(filtered_X_test[index])
ax3.set_title('filtered')

plt.show()

# %%
evaluations=0

for train_index, test_index in splits.copy():
    m= keras.models.clone_model(model)

    m.compile(optimizer="adam", loss=keras.losses.SparseCategoricalCrossentropy(), metrics=['accuracy'])

    train_index, test_index = train_index.tolist(), test_index.tolist()
    x_train, x_test, y_train, y_test = np.array(filtered_X_test)[train_index], np.array(filtered_X_test)[test_index], np.array(Y_test)[train_index], np.array(Y_test)[test_index]

    m.fit(x_train, y_train, epochs=1, batch_size=32)
    evaluations+=m.evaluate(x_test,y_test)[1]

    gc.collect()
print(evaluations/10)
# Out:
# 28/28 [==============================] - 2s 64ms/step - loss: 1.2489 - accuracy: 0.6902
# 4/4 [==============================] - 0s 15ms/step - loss: 15.1385 - accuracy: 0.5051
# 28/28 [==============================] - 2s 62ms/step - loss: 2.0609 - accuracy: 0.6240
# 4/4 [==============================] - 0s 15ms/step - loss: 6.5946 - accuracy: 0.5960
# 28/28 [==============================] - 2s 62ms/step - loss: 1.4355 - accuracy: 0.6487
# 4/4 [==============================] - 0s 15ms/step - loss: 1.8617 - accuracy: 0.6566
# 28/28 [==============================] - 2s 62ms/step - loss: 2.0355 - accuracy: 0.6734
# 4/4 [==============================] - 0s 15ms/step - loss: 2.6222 - accuracy: 0.5859
# 28/28 [==============================] - 2s 62ms/step - loss: 1.9772 - accuracy: 0.6319
# 4/4 [==============================] - 0s 15ms/step - loss: 4.4645 - accuracy: 0.5455
# 28/28 [==============================] - 2s 62ms/step - loss: 1.2881 - accuracy: 0.6857
# 4/4 [==============================] - 0s 15ms/step - loss: 2.0311 - accuracy: 0.7172
# 28/28 [==============================] - 2s 62ms/step - loss: 1.1665 - accuracy: 0.6936
# 4/4 [==============================] - 0s 15ms/step - loss: 2.9690 - accuracy: 0.5859
# 28/28 [==============================] - 2s 62ms/step - loss: 0.9877 - accuracy: 0.6936
# 4/4 [==============================] - 0s 15ms/step - loss: 1.8459 - accuracy: 0.6263
# 28/28 [==============================] - 2s 64ms/step - loss: 1.1071 - accuracy: 0.6712
# 4/4 [==============================] - 0s 14ms/step - loss: 1.5871 - accuracy: 0.6364
# 28/28 [==============================] - 2s 62ms/step - loss: 1.3535 - accuracy: 0.6801
# 4/4 [==============================] - 0s 15ms/step - loss: 1.8121 - accuracy: 0.5556
# 0.6010101020336152
